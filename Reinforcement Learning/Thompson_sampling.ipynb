# %% [markdown]
# <a href="https://colab.research.google.com/github/atharvapatil123/ML_Practice/blob/master/Thompson_sampling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Thompson Sampling

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv('Ads_CTR_Optimisation.csv')

# %% [markdown]
# ## Implementing Thompson Sampling

# %%
import random
N = 10000
d = 10
ads_selected = []
numbers_of_rewards_1 = [0]*10
numbers_of_rewards_0 = [0]*10
total_reward = 0

for n in range(N):
  ad = 0
  max_random = 0
  for i in range(d):
    # beta distribution
    random_beta = random.betavariate(numbers_of_rewards_1[i] + 1, numbers_of_rewards_0[i] + 1)
    # print(random_beta)
    if(random_beta > max_random):
      max_random = random_beta
      ad = i
  
  reward = dataset.values[n, ad]
  if(reward == 1):
    numbers_of_rewards_1[ad] += 1
  else:
    numbers_of_rewards_0[ad] += 1
  ads_selected.append(ad)
  total_reward += reward

# %% [markdown]
# ## Visualising the results - Histogram

# %%
plt.hist(ads_selected)
plt.title('Histogram of ads selections')
plt.xlabel('Ads')
plt.ylabel('Number of times each ad was selected')
plt.show()
