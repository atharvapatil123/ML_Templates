# %% [markdown]
# <a href="https://colab.research.google.com/github/atharvapatil123/ML_Practice/blob/master/Decision_Tree_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# CART:
#
# Classification Trees and Regression Trees
#
# ![Screenshot 2021-12-09 182732.jpg](data:image/jpeg;base64,...)
#
# Splits are called leaves and final leaves are called terminal leaves. The algorithm splits, until the leaf adds some value or it has more than 5% of the data.
#
# ![image.png](data:image/png;base64,...)
#
# We take average of the y-values for each leaf, whenever we have a new value to be predicted.
#
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('Position_Salaries.csv')
x = dataset.iloc[:, 1:2].values
y = dataset.iloc[:, -1].values
# print(x, y)

# %% [markdown]
# Training the Decision tree Regression model on the whole dataset.
#
# No need of Feature Scaling, as prediction results from successive splits.
# Splitting into training and test datasets can be done.

# %%
from sklearn.tree import DecisionTreeRegressor

regressor = DecisionTreeRegressor(random_state=0)
regressor.fit(x, y)
# Out:
# DecisionTreeRegressor(random_state=0)

# %% [markdown]
# Predicting a new result

# %%
y_pred = regressor.predict([[6.5]])
print(y_pred)
# Out:
# [150000.]

# %% [markdown]
# Visualisation

# %%
x_grid = np.arange(min(x), max(x), 0.1)
x_grid = x_grid.reshape(len(x_grid), 1)
plt.scatter(x, y, color='blue')
plt.plot(x_grid, regressor.predict(x_grid), color='red')
plt.show()
# Model is not best adapted for 1-D or 2-D datasets
